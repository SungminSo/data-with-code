# %%
country_list = [
    '교포', '구주 전체', '그루지아', '그리스', '그린랜드', '기 타', '기타 유럽', '네덜란드', '노르웨이', '덴마크', '독일', 
'동독', '라트비아', '러시아', '루마니아', '룩셈부르크', '리투아니아', '리히텐슈타인', '마케도니아', '모나코', '몬테네그로', 
'몰도바', '몰타', '바티칸', '벨기에', '벨라루스', '보스니아ㆍ헤르체고비나', '불가리아', '산마리노', '세르비아', '세르비아 앤 몬테네그로', 
'소련', '스발바드·잠마엔도', '스웨덴', '스위스', '스페인', '슬로바키아', '슬로베니아', '아르메니아', '아이슬란드', '아일랜드', 
'아제르바이잔', '안도라', '알바니아', '에스토니아', '영국', '영국교포', '오스트리아', '우크라이나', '유고슬라비아', '이탈리아', 
'지브롤터', '체코', '코소보', '크로아티아', '파로에군도', '포르투갈', '폴란드', '프랑스', '핀란드', '헝가리', 
'구주 기타', '국적미상', '대양주 전체', '괌', '나우루', '노퍽섬', '뉴질랜드', '뉴칼레도니아', '니우에', '대양주 기타', 
'마샬군도', '미국령 사모아', '미드웨이 군도', '미크로네시아', '바누아투', '북마리아나군도', '사이판', '서사모아', '솔로몬군도', '오스트레일리아', 
'월리스·후트나', '웨이크 군도', '캐롤라인제도', '코코스군도', '쿠크군도', '크리스마스도', '키리바시', '토켈라우', '통가', '투발루', 
'파푸아뉴기니', '팔라우', '프랑스령 극남군도', '프랑스령 폴리네시아', '피지', '핏카인도', '헤어드도·맥도널드군도', '호주령 솔로몬군도', '미주 전체', '가이아나', 
'과테말라', '그레나다', '남조지아·남샌드위치군도', '네덜란드령 안틸레스', '니카라과', '도미니카 공화국', '도미니카연방', '말티니크', '멕시코', '몬트세라트', 
'미국', '미국령 버진군도', '미국령 태평양군도', '미주 기타', '바베이도스', '바하마', '버뮤다', '베네수엘라', '벨리즈', '볼리비아', 
'부베도', '브라질', '세인트 루치아', '세인트 빈센트 그레나딘', '세인트 킷츠 네비스', '세인트피에레도.미쾌론도', '수리남', '아루바', '아르헨티나', '아이티', 
'안길라', '앤티가 바부다', '에스트군도', '에콰도르', '엘살바도르', '영국령 버진군도', '온두라스', '우르과이', '자메이카', '칠레', 
'캐나다', '케이만군도', '코스타리카', '콜롬비아', '쿠바', '터크스ㆍ카이코스군도', '트리니다드ㆍ토바고', '파나마', '파라과이', '페루', 
'포클랜드(말비나스)군도', '푸에토리코', '프랑스령 기아나', '하와이', '승무원', '아시아주 전체', 'GCC', '남예멘(P.D.R)', '네팔', '대만', 
'동티모로', '라오스', '레바논', '마요티', '마카오', '말레이시아', '몰디브', '몽골', '미얀마', '바레인', 
'방글라데시', '베트남', '부탄', '북한', '브루나이', '사우디아라비아', '사이프러스', '스리랑카', '시리아', '시킴', 
'싱가포르', '아랍에미리트', '아시아 기타', '아시아주 기타', '아프가니스탄', '영국령 인도양지역', '예멘', '오만', '요르단', '우즈베키스탄', 
'이라크', '이란', '이스라엘', '인도', '인도네시아', '일본', '중국', '카자흐스탄', '카타르', '캄보디아', 
'쿠웨이트', '키르기스스탄', '타지키스탄', '태국', '터키', '투르크메니스탄', '파키스탄', '팔레스타인', '필리핀', '홍콩', 
'국적미상', '아프리카 전체', '가나', '가봉', '감비아', '공해', '기니', '기니비사우', '나미비아', '나이지리아', 
'남극대륙', '남수단공화국', '남아프리카공화국', '니제르', '라이베리아', '레소토', '르완다', '리비아', '리유니온', '마다가스카르', 
'말라위', '말리', '모로코', '모리셔스', '모리타니', '모잠비크', '베냉', '보츠와나', '부룬디', '부르키나 파소', 
'상투메 프린시페', '서사하라', '세네갈', '세이셸', '세인트 헬레나', '소말리아', '수단', '스와질랜드', '시에라리온', '아프리카 기타', 
'알제리', '앙골라', '에리트리아', '에티오피아', '오트블타', '우간다', '이집트', '자이르', '잠비아', '적도 기니', 
'중앙아프리카공화국', '지부티', '짐바브웨', '차드', '카나리아군도', '카메룬', '카보베르데', '케냐', '코모로', '코트디부아르', 
'콩고', '콩고민주공화국', '탄자니아', '토고', '튀니지'
]
print(len(country_list))
# Out:
# 276

# %%
continents_list = []
for country in country_list[:]:
    if "전체" in country or "대륙" in country:
        continents_list.append(country)
        country_list.remove(country)
        print(country)
        
print("continents_list:", continents_list)
print("country_list:", country_list)
print(len(country_list))
# Out:
# 구주 전체
# 대양주 전체
# 미주 전체
# 아시아주 전체
# 아프리카 전체
# 남극대륙
# continents_list: ['구주 전체', '대양주 전체', '미주 전체', '아시아주 전체', '아프리카 전체', '남극대륙']
# ...

# %%
import pandas as pd

kto_total_201001_202008 = pd.read_excel(f"./files/kto_{country}_201001_202008.xlsx", usecols = 'A:C')
print(kto_total_201001_202008.head())

kto_total = pd.DataFrame(columns =["국적", "기준년월", "관광", "공용", "상용", "유학연수", "기타", "합계"])

for idx in range(kto_total_201001_202008.shape[0] // 5):
    i = idx * 5
    _sum = kto_total_201001_202008.iloc[i, 2] + kto_total_201001_202008.iloc[i+1, 2] + kto_total_201001_202008.iloc[i+2, 2] + kto_total_201001_202008.iloc[i+3, 2] + kto_total_201001_202008.iloc[i+4, 2]
    new_data = [country, f"{kto_total_201001_202008.iloc[i, 0]:g}", kto_total_201001_202008.iloc[i, 2], kto_total_201001_202008.iloc[i+1, 2], kto_total_201001_202008.iloc[i+2, 2], kto_total_201001_202008.iloc[i+3, 2], kto_total_201001_202008.iloc[i+4, 2], _sum]
    kto_total = kto_total.append(pd.Series(new_data, index=kto_total.columns), ignore_index=True)


kto_total
# Out:
#          시점 Unnamed: 1  튀니지(명)
# 0  201001.0         관광      38
# 1       NaN         공용       0
# 2       NaN         상용       1
# 3       NaN       유학연수       5
# 4       NaN         기타      12
#       국적    기준년월  관광 공용 상용 유학연수  기타   합계
# 0    튀니지  201001  38  0  1    5  12   56
# 1    튀니지  201002  28  0  0    2   6   36
# 2    튀니지  201003  54  0  0    1   3   58
# 3    튀니지  201004  62  0  0    1  10   73
# 4    튀니지  201005  98  2  1    1   9  111
# ..   ...     ...  .. .. ..  ...  ..  ...
# 123  튀니지  202004   0  0  0    0  16   16
# 124  튀니지  202005   0  0  0    0  12   12
# 125  튀니지  202006   0  0  1    0  20   21
# 126  튀니지  202007   1  0  1    1  19   22
# 127  튀니지  202008   1  0  0    6  21   28
#
# [128 rows x 8 columns]

# %%
import pandas as pd
import os

kto_total = pd.DataFrame(columns =["국적", "기준년월", "관광", "공용", "상용", "유학연수", "기타", "합계"])

for country in country_list:
    country_tourists = pd.read_excel(f"./files/kto_{country}_201001_202008.xlsx", usecols = 'A:C')
    # for check
    print(country, country_tourists.shape[0])
    
    for idx in range(country_tourists.shape[0] // 5):
        i = idx * 5
        _sum = country_tourists.iloc[i, 2] + country_tourists.iloc[i+1, 2] + country_tourists.iloc[i+2, 2] + country_tourists.iloc[i+3, 2] + country_tourists.iloc[i+4, 2]
        new_data = [country, f"{country_tourists.iloc[i, 0]:g}", country_tourists.iloc[i, 2], country_tourists.iloc[i+1, 2], country_tourists.iloc[i+2, 2], country_tourists.iloc[i+3, 2], country_tourists.iloc[i+4, 2], _sum]
        kto_total = kto_total.append(pd.Series(new_data, index=kto_total.columns), ignore_index=True)
        
    print(country, "Done", kto_total.shape)
    
# for check
print(kto_total.shape)

current_path = os.getcwd()
current_file_path = os.path.join(current_path, 'files/kto_total.csv')
kto_total.to_csv(current_file_path)
# for check
print(current_file_path)
# Out:
# 교포 640
# 교포 Done (128, 8)
# 그루지아 640
# 그루지아 Done (256, 8)
# 그리스 640
# 그리스 Done (384, 8)
# 그린랜드 640
# 그린랜드 Done (512, 8)
# 기 타 640
# 기 타 Done (640, 8)
# 기타 유럽 640
# 기타 유럽 Done (768, 8)
# 네덜란드 640
# 네덜란드 Done (896, 8)
# 노르웨이 640
# 노르웨이 Done (1024, 8)
# 덴마크 640
# 덴마크 Done (1152, 8)
# 독일 640
# 독일 Done (1280, 8)
# 동독 640
# 동독 Done (1408, 8)
# 라트비아 640
# 라트비아 Done (1536, 8)
# 러시아 640
# 러시아 Done (1664, 8)
# 루마니아 640
# 루마니아 Done (1792, 8)
# 룩셈부르크 640
# 룩셈부르크 Done (1920, 8)
# 리투아니아 640
# 리투아니아 Done (2048, 8)
# 리히텐슈타인 640
# 리히텐슈타인 Done (2176, 8)
# 마케도니아 640
# 마케도니아 Done (2304, 8)
# 모나코 640
# 모나코 Done (2432, 8)
# 몬테네그로 640
# 몬테네그로 Done (2560, 8)
# 몰도바 640
# 몰도바 Done (2688, 8)
# 몰타 640
# 몰타 Done (2816, 8)
# 바티칸 640
# 바티칸 Done (2944, 8)
# 벨기에 640
# 벨기에 Done (3072, 8)
# 벨라루스 640
# 벨라루스 Done (3200, 8)
# 보스니아ㆍ헤르체고비나 640
# 보스니아ㆍ헤르체고비나 Done (3328, 8)
# 불가리아 640
# 불가리아 Done (3456, 8)
# 산마리노 640
# 산마리노 Done (3584, 8)
# 세르비아 640
# 세르비아 Done (3712, 8)
# 세르비아 앤 몬테네그로 640
# 세르비아 앤 몬테네그로 Done (3840, 8)
# ...

# %%
import os

current_path = os.getcwd()
current_file_path = os.path.join(current_path, "files\kto_total.csv")
print(current_file_path)
# Out:
# C:\Users\gram\Desktop\Projects\data-with-code\tourists_event\files\kto_total.csv
