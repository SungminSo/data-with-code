# %%
import pandas as pd

raw_total = pd.read_excel('./files/crawling_jeju.xlsx')
raw_total.head()
# Out:
#                                              content  data like  watch place  \
# 0  숙성고기의 끝판왕제주육대표 최상급 한우와제주 흑돼지를진공 포장하여 1.5도 물에50...   NaN    0  2,817   NaN
# 1  (광고)제주도민들도 인정한 맛집 #운정...   NaN    0    457   NaN
# 2  비주얼 그대로의 두툼한 흑돼지입니다⠀화산암반수를 먹인무항생제의 제주 흑돼지!품질을 ...   NaN    0  4,813   NaN
# 3  광고★배달도가능?애월해안도로와제주공항근처 사이에이춘옥 원조고등어쌈밥👍네이버할인은 물...   NaN    0    280   NaN
# 4  (광고)지만 꼭 추천해주고 싶은제주도 먹부림 코스!⠀시작은 역시👏제주도 흑돼지로제주...   NaN    0  2,633   NaN
#
#                                                 tags  Unnamed: 0        date
# 0  ['#제주도맛집', '#제주공항근처맛집', '#제주시맛집', '#제주흑돼지맛집', ...           0  2021-01-01
# 1  ['#운정이네.제주 중문에 위치한 아주아주 ᄀ...           1  2021-01-02
# 2  ['#중문맛집 ', '#서귀포맛집', '#제주맛집 ', '#제주도맛집', '#제주중...           2  2020-12-31
# 3  ['#제주도맛집 ', '#제주맛집 ', '#애월맛집', '#고등어쌈밥 ', '#애월...           3  2021-01-02
# 4  ['#제주도맛집', '#제주가볼만한곳', '#제주애월맛집', '#제주핫플', '#제...           4  2021-01-03

# %%
# 위치 정보별 빈도수 집계
location_counts = raw_total['place'].value_counts()
print(location_counts)
# Out:
# Jeju                 28
# 환상의 섬 Jeju Island    25
# Jeju-do              22
# 제주도                   8
# 제주고산리유적               8
#                      ..
# 이호테우해변                1
# 천연불맛 불쇼 미온당           1
# 미스틱 3도                1
# 함덕해수욕장                1
# 하도미술관                 1
# Name: place, Length: 192, dtype: int64

# %%
location_counts_df = pd.DataFrame(location_counts)
location_counts_df.head()
# Out:
#                    place
# Jeju                  28
# 환상의 섬 Jeju Island     25
# Jeju-do               22
# 제주도                    8
# 제주고산리유적                8

# %%
location_counts_df.to_excel('./files/location_counts.xlsx')

# %%
locations = list(location_counts.index)
locations
# Out:
# ['Jeju',
#  '환상의 섬 Jeju Island',
#  'Jeju-do',
#  '제주도',
#  '제주고산리유적',
#  '고래배꼽',
#  'Jungle Book by Alice',
#  '동백포레스트',
#  '제주도 Jeju Island',
#  'Jeju Island',
#  '황우지해안',
#  '사이카레',
#  '우도 牛岛 Udo Island, South Korea',
#  '오엘이에프커피',
#  'Seogwipo, Jeju Island, South Korea',
#  '새별오름',
#  '제주시청어딘가',
#  '휴애리 자연생활공원',
#  '1100고지 경치 좋은 곳',
#  '제주 함덕 서우봉 해변',
#  '제주 함덕카페 라라떼',
#  'Seoul, Korea',
#  '제주국제공항',
#  '더로맨틱 _ 내생에 가장 아름다운 날들',
#  '요요무문',
#  '인생밥집',
#  '제주동백수목원',
#  '푸른섬 제주도',
#  '인스밀',
#  'LAVI De ATLAN HOTEL',
#  '아뜰리에 효',
#  '제주 흑돼지 맛집 대박이네',
#  '삼다수숲길',
#  '제주 구좌읍 세화리',
#  'Jeju Island, South Korea - 제주도',
#  '제주도 하도리',
#  '서귀포',
#  '제주공항근처',
#  '제주귀더크',
#  '카멜리아 힐',
#  '대한민국 大韓民國',
#  '제주도 휘닉스아일랜드 힐리우스별장',
#  '산록도로',
#  '순전이해녀김밥',
#  '귤꽃다락',
#  '금능해수욕장',
#  '카페록키',
#  '제주 코코몽에코파크',
#  '선녀탕',
#  '카페뮤로',
#  '제주도 곽지해수욕장',
#  '쌩텀펜션',
#  '삼화지구',
#  '카페록록 Loklok',
#  '돌집 by신대장',
#  '허니문하우스',
#  'LOTTE HOTEL JEJU 롯데호텔제주',
#  'One and only - 원앤온리 제주',
#  'Nasillonner_나지요네',
#  '제주도 애월읍',
#  '대평리',
#  '온새미로펜션',
#  'Busan 釜山, South Korea',
#  'Incheon, South Korea',
#  'Seishun - 세이슌',
#  '1100고지',
#  'Happy New Year 2021',
#  '연 과자점',
#  '주비카페',
#  '미요',
#  '비밀의숲',
#  'All that JEJU (올댓제주)',
#  'The Shilla Jeju',
#  '서울국수가게',
#  '동광마을',
#  'the cliff jeju - 더클리프 제주',
#  '카페 노티드 제주 애월 - Cafe Knotted Jeju Aewol',
#  '두베하우스',
#  '애월파티장 설레임',
#  '비자림',
#  '탱테일',
#  '오설록티뮤지엄',
#  '루페이퍼 Rupaper',
#  'Hamdeok Jeju',
#  '착한스시',
#  '피즈',
#  '나니아 Narnia jeju cuisine & cafe',
#  '제주종합경기장',
#  'Starbucks - Jeju Jungmun DT',
#  'Busan, South Korea',
#  '한경면 저지리',
#  '제주시청',
#  '이에르바',
#  '정이가네 소한마리국밥',
#  'Osulloc Tea Museum',
#  '하이엔드 제주',
#  '이듸',
#  '마담나탈리소셜클럽',
#  '제주 스시앤',
#  'Enough, 이너프',
#  '면뽑는선생만두빚는아내',
#  '제주앞바다해물탕',
#  '모레기동 타잔',
#  '협재식물원',
#  '스누피가든',
#  'ディズニーランド',
#  '제주도 비체올린',
#  '도두해안도로',
#  '장백산',
#  '제주도 서귀포 동홍동',
#  '팔공산',
#  '섭섭이네',
#  '인자갈비',
#  '제주 애월',
#  '홍찜닭',
#  '나이롱책방',
#  '노형동 연탄과친한돼지',
#  '하늘키즈가족펜션',
#  'Texia - 텍시아',
#  '제주타투_민아트',
#  '뽈살집서귀포점',
#  '바당고지',
#  '뵤뵤카페',
#  '먹고정',
#  '구남동',
#  '협재해수욕장',
#  '용머리해안',
#  '제주시 일도이동',
#  '광치기해변',
#  '한라산',
#  '평대스낵',
#  '제주또시랑',
#  '김녕해수욕장',
#  'Cafè 새빌',
#  '제주뚝배기',
#  '베어포레스트',
#  '카페한라산',
#  '성산읍 수산리',
#  '검은노루',
#  '용연구름다리',
#  '사려니숲길',
#  '수목원길 야시장',
#  'Tropical Hideaway Hotel & Brunch & Pub',
#  '참솔',
#  '아르떼뮤지엄 Arte Museum',
#  '생각의숲생각의술',
#  '양가형제',
#  '제주도 새별오름',
#  '집에서',
#  '일루다',
#  '제주그란데',
#  '봉주르마담',
#  '노꼬메오름',
#  'Beduri Square 배두리광장',
#  '난드르커피',
#  '김녕해안도로',
#  'GROOV JEJU',
#  '다니쉬',
#  '성산일출봉',
#  '신창풍차해안도로',
#  '해외여행',
#  '몽상드애월',
#  'M1971 요트투어',
#  '월정리해변',
#  '비양도',
#  '표선 해비치해수욕장',
#  '조천읍 북촌리',
#  '제주시 아라동',
#  '하례정원',
#  '제주레포츠랜드',
#  'Hidden Cliff / 히든 클리프',
#  '코코메아',
#  '한림해안도로',
#  '여유로이',
#  '홍연화관',
#  '팔공산 비로봉',
#  '제주고집',
#  '녹산로',
#  '도두해안',
#  '볼수록 제주',
#  '애월해안도로',
#  'Cafe 어떤하루',
#  '공방:하루_반',
#  '고집돌우럭-gozipfish',
#  '제주도 한림',
#  '포토이즘',
#  '안덕면 감산리',
#  '이호테우해변',
#  '천연불맛 불쇼 미온당',
#  '미스틱 3도',
#  '함덕해수욕장',
#  '하도미술관']
